# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.reshape(-1, 28, 28, 1) / 255.0
x_test = x_test.reshape(-1, 28, 28, 1) / 255.0
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

# Define the first CNN architecture
model_1 = Sequential()
model_1.add(Conv2D(16, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model_1.add(MaxPooling2D((2, 2)))
model_1.add(Flatten())
model_1.add(Dense(64, activation='relu'))
model_1.add(Dense(10, activation='softmax'))

# Define the second CNN architecture
model_2 = Sequential()
model_2.add(Conv2D(8, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model_2.add(MaxPooling2D((2, 2)))
model_2.add(Flatten())
model_2.add(Dense(16, activation='relu'))
model_2.add(Dense(10, activation='softmax'))

# Define the third CNN architecture
model_3 = Sequential()
model_3.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model_3.add(MaxPooling2D((2, 2)))
model_3.add(Flatten())
model_3.add(Dense(256, activation='relu'))
model_3.add(Dense(10, activation='softmax'))

# Compile and train the models
models = [model_1, model_2, model_3]
history = []

for model in models:
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    model.fit(x_train, y_train, batch_size=128, epochs=10, verbose=1)
    history.append(model.evaluate(x_test, y_test, verbose=0))

# Create a comparison table
table = pd.DataFrame(history, columns=['Loss', 'Accuracy'])
table.index = ['Model 1', 'Model 2', 'Model 3']
print(table)
# Out:
# ...
# 11490434/11490434 [==============================] - 5s 0us/step
# Epoch 1/10
# 469/469 [==============================] - 23s 40ms/step - loss: 0.2940 - accuracy: 0.9166
# Epoch 2/10
# 469/469 [==============================] - 20s 42ms/step - loss: 0.0971 - accuracy: 0.9724
# Epoch 3/10
# 469/469 [==============================] - 20s 42ms/step - loss: 0.0661 - accuracy: 0.9810
# Epoch 4/10
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0508 - accuracy: 0.9853
# Epoch 5/10
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0414 - accuracy: 0.9875
# Epoch 6/10
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0346 - accuracy: 0.9896
# Epoch 7/10
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0289 - accuracy: 0.9911
# Epoch 8/10
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0244 - accuracy: 0.9926
# Epoch 9/10
# ...
